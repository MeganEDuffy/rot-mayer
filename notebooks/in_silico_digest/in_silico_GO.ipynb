# %% [markdown]
# ### Evaluating and visualizing gene ontology (GO) terms associated with algal and bacterial proteins during degradation experiment
#
# #### Beginning with: GO term abundances from UniPept LCA of tryptic peptides generated from an in silico digestion of identified algal proteins (many of which were found with non tryptic searches, so UniPept not feasible).
#
# #### Goal: heatmaps of algal and bacterial GO terms over the 4 timepoints

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from functools import reduce

# %%
# read the data into pandas dataframes
D0_TD = pd.read_csv("/home/millieginty/Documents/git-repos/rot-mayer/analyses/unipept/GO-terms/trypsin-dig-proteinIDs/322-DB-protein-diatom-cc.csv")

# concatenate GO-term and Name columns
D0_TD['GO term'] = D0_TD['GO-term'] + " " + D0_TD['Name']
del D0_TD['GO-term']
del D0_TD['Name']

print('322:', len(D0_TD))

# read the data into pandas dataframes
D2_TD = pd.read_csv("/home/millieginty/Documents/git-repos/rot-mayer/analyses/unipept/GO-terms/trypsin-dig-proteinIDs/323-DB-protein-diatom-cc.csv")

# concatenate GO-term and Name columns
D2_TD['GO term'] = D2_TD['GO-term'] + " " + D2_TD['Name']
del D2_TD['GO-term']
del D2_TD['Name']

print('323:', len(D2_TD))

# read the data into pandas dataframes
D5_TD = pd.read_csv("/home/millieginty/Documents/git-repos/rot-mayer/analyses/unipept/GO-terms/trypsin-dig-proteinIDs/324-DB-protein-diatom-cc.csv")

# concatenate GO-term and Name columns
D5_TD['GO term'] = D5_TD['GO-term'] + " " + D5_TD['Name']
del D5_TD['GO-term']
del D5_TD['Name']

print('324:', len(D5_TD))

# read the data into pandas dataframes
D12_TD = pd.read_csv("/home/millieginty/Documents/git-repos/rot-mayer/analyses/unipept/GO-terms/trypsin-dig-proteinIDs/325-DB-protein-diatom-cc.csv")

# concatenate GO-term and Name columns
D12_TD['GO term'] = D12_TD['GO-term'] + " " + D12_TD['Name']
del D12_TD['GO-term']
del D12_TD['Name']

print('325:', len(D12_TD))
# Out:
# 322: 50
# 323: 76
# 324: 26
# 325: 16

# %%
# read the data into pandas dataframes
D0_ND = pd.read_csv("/home/millieginty/Documents/git-repos/rot-mayer/analyses/unipept/GO-terms/trypsin-dig-proteinIDs/329-DB-protein-diatom-cc.csv")

# concatenate GO-term and Name columns
D0_ND['GO term'] = D0_ND['GO-term'] + " " + D0_ND['Name']
del D0_ND['GO-term']
del D0_ND['Name']

print('329:', len(D0_ND))

# read the data into pandas dataframes
D2_ND = pd.read_csv("/home/millieginty/Documents/git-repos/rot-mayer/analyses/unipept/GO-terms/trypsin-dig-proteinIDs/330-DB-protein-diatom-cc.csv")

# concatenate GO-term and Name columns
D2_ND['GO term'] = D2_ND['GO-term'] + " " + D2_ND['Name']
del D2_ND['GO-term']
del D2_ND['Name']

print('330:', len(D2_ND))

# read the data into pandas dataframes
D5_ND = pd.read_csv("/home/millieginty/Documents/git-repos/rot-mayer/analyses/unipept/GO-terms/trypsin-dig-proteinIDs/331-DB-protein-diatom-cc.csv")

# concatenate GO-term and Name columns
D5_ND['GO term'] = D5_ND['GO-term'] + " " + D5_ND['Name']
del D5_ND['GO-term']
del D5_ND['Name']

print('331:', len(D5_ND))

# read the data into pandas dataframes
D12_ND = pd.read_csv("/home/millieginty/Documents/git-repos/rot-mayer/analyses/unipept/GO-terms/trypsin-dig-proteinIDs/332-DB-protein-diatom-cc.csv")

# concatenate GO-term and Name columns
D12_ND['GO term'] = D12_ND['GO-term'] + " " + D12_ND['Name']
del D12_ND['GO-term']
del D12_ND['Name']

print('332:', len(D12_ND))
# Out:
# 329: 23
# 330: 35
# 331: 11
# 332: 7

# %%
# join the dataframes
d0d2 = pd.merge(D0_TD, D2_TD, on = ['GO term'], how = 'outer')

print('combined rows:', len(d0d2))

# rename columns
names = ['Day 0 TD', 'GO term', 'Day 2 TD']
         
d0d2.columns = names
# Out:
# combined rows: 86

# %%
# join the dataframes
d0d2d5 = pd.merge(d0d2, D5_TD, on = ['GO term'], how = 'outer')

print('combined rows:', len(d0d2d5))

# rename columns
names = ['Day 0 TD', 'GO term', 'Day 2 TD', 'Day 5 TD']
         
d0d2d5.columns = names
# Out:
# combined rows: 87

# %%
# join the dataframes
d0d2d5d12 = pd.merge(d0d2d5, D12_TD, on = ['GO term'], how = 'outer')

print('combined rows:', len(d0d2d5d12))

# rename columns
names = ['Day 0 TD', 'GO term', 'Day 2 TD', 'Day 5 TD', 'Day 12 TD']
         
d0d2d5d12.columns = names
# Out:
# combined rows: 88
#    Day 0 TD                                    GO term  Day 2 TD  Day 5 TD  \
# 0     197.0  GO:0016021 integral component of membrane     155.0     115.0
# 1     139.0  GO:0009535 chloroplast thylakoid membrane     138.0      78.0
# 2      64.0                       GO:0005737 cytoplasm      93.0       8.0
# 3      59.0                     GO:0009507 chloroplast      89.0      49.0
# 4      50.0                         GO:0005829 cytosol      85.0       NaN
#
#    Day 12 TD
# 0       91.0
# 1       74.0
# 2        NaN
# 3       42.0
# 4        NaN

# %%
# join the dataframes
d0d2d5d12d0 = pd.merge(d0d2d5d12, D0_ND, on = ['GO term'], how = 'outer')

print('combined rows:', len(d0d2d5d12d0))

# rename columns
names = ['Day 0 TD', 'GO term', 'Day 2 TD', 'Day 5 TD', 'Day 12 TD', 'Day 0 ND']
         
d0d2d5d12d0.columns = names
# Out:
# combined rows: 90

# %%
# join the dataframes
d0d2d5d12d0d2 = pd.merge(d0d2d5d12d0, D2_ND, on = ['GO term'], how = 'outer')

print('combined rows:', len(d0d2d5d12d0d2))

# rename columns
names = ['Day 0 TD', 'GO term', 'Day 2 TD', 'Day 5 TD', 'Day 12 TD', 'Day 0 ND', 'Day 2 ND']
         
d0d2d5d12d0d2.columns = names
# Out:
# combined rows: 90

# %%
# join the dataframes
d0d2d5d12d0d2d5 = pd.merge(d0d2d5d12d0d2, D5_ND, on = ['GO term'], how = 'outer')

print('combined rows:', len(d0d2d5d12d0d2d5))

# rename columns
names = ['Day 0 TD', 'GO term', 'Day 2 TD', 'Day 5 TD', 'Day 12 TD', 'Day 0 ND', 'Day 2 ND', 'Day 5 ND']
         
d0d2d5d12d0d2d5.columns = names
# Out:
# combined rows: 90

# %%
# join the dataframes
d0d2d5d12d0d2d5d12 = pd.merge(d0d2d5d12d0d2d5, D12_ND, on = ['GO term'], how = 'outer')

print('combined rows:', len(d0d2d5d12d0d2d5d12))

# rename columns
names = ['Day 0 TD', 'GO term', 'Day 2 TD', 'Day 5 TD', 'Day 12 TD', \
         'Day 0 ND', 'Day 2 ND', 'Day 5 ND', 'Day 12 ND']
         
d0d2d5d12d0d2d5d12.columns = names

d0d2d5d12d0d2d5d12.set_index('GO term', inplace = True)

combineGO = d0d2d5d12d0d2d5d12

combineGO.head()
# Out:
# combined rows: 90
#                                            Day 0 TD  Day 2 TD  Day 5 TD  \
# GO term
# GO:0016021 integral component of membrane     197.0     155.0     115.0
# GO:0009535 chloroplast thylakoid membrane     139.0     138.0      78.0
# GO:0005737 cytoplasm                           64.0      93.0       8.0
# GO:0009507 chloroplast                         59.0      89.0      49.0
# GO:0005829 cytosol                             50.0      85.0       NaN
#
#                                            Day 12 TD  Day 0 ND  Day 2 ND  \
# GO term
# GO:0016021 integral component of membrane       91.0      74.0     103.0
# GO:0009535 chloroplast thylakoid membrane       74.0      53.0     120.0
# GO:0005737 cytoplasm                             NaN       3.0      25.0
# GO:0009507 chloroplast                          42.0      23.0      61.0
# GO:0005829 cytosol                               NaN      28.0      48.0
#
# ...

# %%
# plot heatmap

fig, ax = plt.subplots(figsize=(15,20))

ax = sns.heatmap(combineGO, cmap="Greens", annot=True, linecolor = 'grey', linewidths=.01, \
                square=False, cbar_kws={'label': '# of peptides'})

ax.set_ylabel('')

# turn the axis label
for item in ax.get_yticklabels():
    item.set_rotation(0)

for item in ax.get_xticklabels():
    item.set_rotation(45)

# %%
# plot heatmap

f,(ax1,ax2) = plt.subplots(1,2,sharey=True, sharex=True, figsize=(6, 10))

plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.1, hspace=0.01)

maskn = diatom_endo.isnull()
maskx = diatom_exo.isnull()

g1 = sns.heatmap(diatom_endo,cmap="Greens",cbar=False,ax=ax1, linecolor = 'grey', linewidths=.01, \
                 mask=maskn, square=True, annot=True)
g1.set_ylabel('')
g1.set_xticklabels(diatom_endo.columns, rotation=40)
g1.set_xlabel('Endogenous', fontsize = 14)


g2 = sns.heatmap(diatom_exo,cmap="Greens",cbar=True,ax=ax2, linecolor = 'grey', linewidths=.01, \
                mask=maskx, vmin = 0, square=True, annot=True, cbar_kws={'label': '# of peptides'})
g2.set_ylabel('')
g2.set_xticklabels(diatom_exo.columns, rotation=40)
g2.set_xlabel('Exogenous', fontsize = 14)
# Out:
# Text(0.5, 101.65714285714279, 'Exogenous')

# %%
# plot heatmap

f,(ax1,ax2) = plt.subplots(1,2,sharey=True, figsize=(6, 10))

plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.1, hspace=0.01)

mask = diatom.isnull()
maskb = bacteria.isnull()


g1 = sns.heatmap(diatom,cmap="Greens",cbar=False,ax=ax1, linecolor = 'grey', linewidths=.01, \
                 mask=mask, square=True)
g1.set_ylabel('')
g1.set_xticklabels(diatom.columns, rotation=40)
g1.set_xlabel('Diatoms', fontsize = 14)


g2 = sns.heatmap(bacteria,cmap="Greens",cbar=True,ax=ax2, linecolor = 'grey', linewidths=.01, \
                mask=maskb, square=True, cbar_kws={'label': '# of peptides'})
g2.set_ylabel('')
g2.set_xticklabels(bacteria.columns, rotation=40)
g2.set_xlabel('Bacteria', fontsize = 14)
# Out:
# Text(0.5, 69.0, 'Bacteria')

# %%
corr = np.corrcoef(np.random.randn(10, 200))
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
g = sns.heatmap(corr, mask=mask, vmax=.3, square=True)
g.set_facecolor('xkcd:salmon')

corr
# Out:
# array([[ 1.        ,  0.01112885,  0.09118655, -0.00392899,  0.04372059,
#         -0.12416781, -0.02233528, -0.02973144,  0.07789597,  0.02653949],
#        [ 0.01112885,  1.        , -0.12311011, -0.04596409, -0.07721531,
#          0.05886169, -0.08877293, -0.05940085,  0.12236971,  0.08831269],
#        [ 0.09118655, -0.12311011,  1.        ,  0.02149686,  0.09598815,
#         -0.078215  , -0.02154418, -0.02758756,  0.08430617, -0.02890587],
#        [-0.00392899, -0.04596409,  0.02149686,  1.        ,  0.08221417,
#         -0.02421263, -0.03793206,  0.05579023, -0.01821216,  0.00804485],
#        [ 0.04372059, -0.07721531,  0.09598815,  0.08221417,  1.        ,
#         -0.05021376,  0.03489411,  0.01180592, -0.1046717 ,  0.16196212],
#        [-0.12416781,  0.05886169, -0.078215  , -0.02421263, -0.05021376,
#          1.        , -0.0809692 , -0.01539847,  0.0460595 , -0.0359788 ],
#        [-0.02233528, -0.08877293, -0.02154418, -0.03793206,  0.03489411,
# ...

# %%
# plot heatmap
ax = sns.heatmap(bacteria, cmap="Greens")

ax.set_ylabel('')

# turn the axis label
for item in ax.get_yticklabels():
    item.set_rotation(0)

for item in ax.get_xticklabels():
    item.set_rotation(90)

# save figure
#plt.savefig('seabornPandas.png', dpi=100)
plt.show()

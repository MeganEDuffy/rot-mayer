# %% [markdown]
# ### Comparing trypsin digested and non digested  peptides for each _T. weisflogii_ rot sample:
#
# Starting with:
#
#     Peaks de novo results of PTM-optimized sequencing, with leucine and isoleuce equated (DN)
#     PeaksDB de novo-assisted results from PTM-optimized searches, with leucine and isoleuce equated (DB)
#
# Goal:
#
#     Venn diagrams of de novo and database peptide for each timepoint
#     Venn diagrams of proteins predicted from each peptide set at each timepoint
#     Venn diagram of peptide GO terms (cellular compartment, to start)
#
# Using:
#
#     - pandas
#     - matplotlib
#     - numpy
#     - venn2

# %%
# LIBRARIES
#import pandas library for working with tabular data
import os
os.getcwd()
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import kde
#import regular expresson (regex)
import re
#from matplotlib_venn import venn2
#from matplotlib_venn import venn3
from matplotlib_venn import venn2, venn2_circles
#check pandas version
pd.__version__
# Out:
# '1.0.5'

# %%
# Day 0 database peptides

plt.figure(figsize=(4,5))
v = venn2(subsets=(710, 176, 67), \
          set_labels = ('Trypsin-digested DB', 'Non-digested DB'))
v.get_patch_by_id('100').set_alpha(1.0)

v.get_patch_by_id('100').set_color('#e6550d')

v.get_patch_by_id('100').set_lw(1.5)
v.get_patch_by_id('010').set_lw(1.5)


plt.tight_layout()

# save figure in analysis and also in manuscript git repos
#plt.savefig("/home/millieginty/Documents/git-repos/2017-etnp/data/pro2020/RAL4_95_MED2_trypsin/TPP/MED4-Comet_ProtProp-overlap.png", dpi=300, transparent=True)
#plt.savefig("/home/millieginty/Documents/git-repos/denovo-etnp/MED4-Comet_ProtProp-overlap.png", dpi=300, transparent=True)
plt.show()

# %%
# Day 2 database peptides

plt.figure(figsize=(4,5))
v = venn2(subsets=(737, 1678, 344), \
          set_labels = ('Trypsin-digested DB', 'Non-digested DB'))
v.get_patch_by_id('100').set_alpha(1.0)

v.get_patch_by_id('100').set_color('#e6550d')

v.get_patch_by_id('100').set_lw(1.5)
v.get_patch_by_id('010').set_lw(1.5)


plt.tight_layout()

# save figure in analysis and also in manuscript git repos
#plt.savefig("/home/millieginty/Documents/git-repos/2017-etnp/data/pro2020/RAL4_95_MED2_trypsin/TPP/MED4-Comet_ProtProp-overlap.png", dpi=300, transparent=True)
#plt.savefig("/home/millieginty/Documents/git-repos/denovo-etnp/MED4-Comet_ProtProp-overlap.png", dpi=300, transparent=True)
plt.show()

# %%
# Day 5 database peptides

plt.figure(figsize=(4,5))
v = venn2(subsets=(452, 157, 59), \
          set_labels = ('Trypsin-digested DB', 'Non-digested DB'))
v.get_patch_by_id('100').set_alpha(1.0)

v.get_patch_by_id('100').set_color('#e6550d')

v.get_patch_by_id('100').set_lw(1.5)
v.get_patch_by_id('010').set_lw(1.5)


plt.tight_layout()

# save figure in analysis and also in manuscript git repos
#plt.savefig("/home/millieginty/Documents/git-repos/2017-etnp/data/pro2020/RAL4_95_MED2_trypsin/TPP/MED4-Comet_ProtProp-overlap.png", dpi=300, transparent=True)
#plt.savefig("/home/millieginty/Documents/git-repos/denovo-etnp/MED4-Comet_ProtProp-overlap.png", dpi=300, transparent=True)
plt.show()

# %%
# Day 12 database peptides

plt.figure(figsize=(4,5))
v = venn2(subsets=(275, 43, 10), \
          set_labels = ('Trypsin-digested DB', 'Non-digested DB'))
v.get_patch_by_id('100').set_alpha(1.0)

v.get_patch_by_id('100').set_color('#e6550d')

v.get_patch_by_id('100').set_lw(1.5)
v.get_patch_by_id('010').set_lw(1.5)


plt.tight_layout()

# save figure in analysis and also in manuscript git repos
#plt.savefig("/home/millieginty/Documents/git-repos/2017-etnp/data/pro2020/RAL4_95_MED2_trypsin/TPP/MED4-Comet_ProtProp-overlap.png", dpi=300, transparent=True)
#plt.savefig("/home/millieginty/Documents/git-repos/denovo-etnp/MED4-Comet_ProtProp-overlap.png", dpi=300, transparent=True)
plt.show()

# %%
# Day 0 de novo peptides

plt.figure(figsize=(4,5))
v = venn2(subsets=(4139, 1743, 87), \
          set_labels = ('Trypsin-digested DN', 'Non-digested DN'))
v.get_patch_by_id('100').set_alpha(1.0)

v.get_patch_by_id('100').set_color('#e6550d')

v.get_patch_by_id('100').set_lw(1.5)
v.get_patch_by_id('010').set_lw(1.5)


plt.tight_layout()

# save figure in analysis and also in manuscript git repos
#plt.savefig("/home/millieginty/Documents/git-repos/2017-etnp/data/pro2020/RAL4_95_MED2_trypsin/TPP/MED4-Comet_ProtProp-overlap.png", dpi=300, transparent=True)
#plt.savefig("/home/millieginty/Documents/git-repos/denovo-etnp/MED4-Comet_ProtProp-overlap.png", dpi=300, transparent=True)
plt.show()

# %%
# Day 2 de novo peptides

plt.figure(figsize=(4,5))
v = venn2(subsets=(4381, 3111, 232), \
          set_labels = ('Trypsin-digested DN', 'Non-digested DN'))
v.get_patch_by_id('100').set_alpha(1.0)

v.get_patch_by_id('100').set_color('#e6550d')

v.get_patch_by_id('100').set_lw(1.5)
v.get_patch_by_id('010').set_lw(1.5)


plt.tight_layout()

# save figure in analysis and also in manuscript git repos
#plt.savefig("/home/millieginty/Documents/git-repos/2017-etnp/data/pro2020/RAL4_95_MED2_trypsin/TPP/MED4-Comet_ProtProp-overlap.png", dpi=300, transparent=True)
#plt.savefig("/home/millieginty/Documents/git-repos/denovo-etnp/MED4-Comet_ProtProp-overlap.png", dpi=300, transparent=True)
plt.show()

# %%
# Day 5 de novo peptides

plt.figure(figsize=(4,5))
v = venn2(subsets=(3136, 1970, 90), \
          set_labels = ('Trypsin-digested DN', 'Non-digested DN'))
v.get_patch_by_id('100').set_alpha(1.0)

v.get_patch_by_id('100').set_color('#e6550d')

v.get_patch_by_id('100').set_lw(1.5)
v.get_patch_by_id('010').set_lw(1.5)


plt.tight_layout()

# save figure in analysis and also in manuscript git repos
#plt.savefig("/home/millieginty/Documents/git-repos/2017-etnp/data/pro2020/RAL4_95_MED2_trypsin/TPP/MED4-Comet_ProtProp-overlap.png", dpi=300, transparent=True)
#plt.savefig("/home/millieginty/Documents/git-repos/denovo-etnp/MED4-Comet_ProtProp-overlap.png", dpi=300, transparent=True)
plt.show()

# %%
# Day 12 de novo peptides

plt.figure(figsize=(4,5))
v = venn2(subsets=(4567, 2431, 160), \
          set_labels = ('Trypsin-digested DN', 'Non-digested DN'))
v.get_patch_by_id('100').set_alpha(1.0)

v.get_patch_by_id('100').set_color('#e6550d')

v.get_patch_by_id('100').set_lw(1.5)
v.get_patch_by_id('010').set_lw(1.5)


plt.tight_layout()

# save figure in analysis and also in manuscript git repos
#plt.savefig("/home/millieginty/Documents/git-repos/2017-etnp/data/pro2020/RAL4_95_MED2_trypsin/TPP/MED4-Comet_ProtProp-overlap.png", dpi=300, transparent=True)
#plt.savefig("/home/millieginty/Documents/git-repos/denovo-etnp/MED4-Comet_ProtProp-overlap.png", dpi=300, transparent=True)
plt.show()

# %%
# Day 0 DB protein overlap

plt.figure(figsize=(5,5))
v = venn2(subsets=(301, 23, 68), \
          set_labels = ('Trypsin-digested T. weiss proteins', 'Non-digested T. weiss proteins'))
v.get_patch_by_id('100').set_alpha(1.0)

v.get_patch_by_id('100').set_color('#dd1c77')
v.get_patch_by_id('010').set_color('#fec44f')
#v.get_patch_by_id('001').set_color('#31a354')

v.get_patch_by_id('100').set_lw(1.5)
v.get_patch_by_id('010').set_lw(1.5)


plt.tight_layout()

# save figure in analysis and also in manuscript git repos
#plt.savefig("/home/millieginty/Documents/git-repos/2017-etnp/data/pro2020/RAL4_95_MED2_trypsin/TPP/MED4-Comet_ProtProp-overlap.png", dpi=300, transparent=True)
#plt.savefig("/home/millieginty/Documents/git-repos/denovo-etnp/MED4-Comet_ProtProp-overlap.png", dpi=300, transparent=True)
plt.show()

# %%
# Day 2 DB protein overlap

plt.figure(figsize=(5,5))
v = venn2(subsets=(430, 54, 117), \
          set_labels = ('Trypsin-digested T. weiss proteins', 'Non-digested T. weiss proteins'))
v.get_patch_by_id('100').set_alpha(1.0)

v.get_patch_by_id('100').set_color('#dd1c77')
v.get_patch_by_id('010').set_color('#fec44f')
#v.get_patch_by_id('001').set_color('#31a354')

v.get_patch_by_id('100').set_lw(1.5)
v.get_patch_by_id('010').set_lw(1.5)


plt.tight_layout()

# save figure in analysis and also in manuscript git repos
#plt.savefig("/home/millieginty/Documents/git-repos/2017-etnp/data/pro2020/RAL4_95_MED2_trypsin/TPP/MED4-Comet_ProtProp-overlap.png", dpi=300, transparent=True)
#plt.savefig("/home/millieginty/Documents/git-repos/denovo-etnp/MED4-Comet_ProtProp-overlap.png", dpi=300, transparent=True)
plt.show()

# %%
# Day 5 DB protein overlap

plt.figure(figsize=(5,5))
v = venn2(subsets=(150, 13, 42), \
          set_labels = ('Trypsin-digested T. weiss proteins', 'Non-digested T. weiss proteins'))
v.get_patch_by_id('100').set_alpha(1.0)

v.get_patch_by_id('100').set_color('#dd1c77')
v.get_patch_by_id('010').set_color('#fec44f')
#v.get_patch_by_id('001').set_color('#31a354')

v.get_patch_by_id('100').set_lw(1.5)
v.get_patch_by_id('010').set_lw(1.5)


plt.tight_layout()

# save figure in analysis and also in manuscript git repos
#plt.savefig("/home/millieginty/Documents/git-repos/2017-etnp/data/pro2020/RAL4_95_MED2_trypsin/TPP/MED4-Comet_ProtProp-overlap.png", dpi=300, transparent=True)
#plt.savefig("/home/millieginty/Documents/git-repos/denovo-etnp/MED4-Comet_ProtProp-overlap.png", dpi=300, transparent=True)
plt.show()

# %%
# Day 5 DB protein overlap

plt.figure(figsize=(5,5))
v = venn2(subsets=(150, 13, 42), \
          set_labels = ('Trypsin-digested T. weiss proteins', 'Non-digested T. weiss proteins'))
v.get_patch_by_id('100').set_alpha(1.0)

v.get_patch_by_id('100').set_color('#dd1c77')
v.get_patch_by_id('010').set_color('#fec44f')
#v.get_patch_by_id('001').set_color('#31a354')

v.get_patch_by_id('100').set_lw(1.5)
v.get_patch_by_id('010').set_lw(1.5)


plt.tight_layout()

# save figure in analysis and also in manuscript git repos
#plt.savefig("/home/millieginty/Documents/git-repos/2017-etnp/data/pro2020/RAL4_95_MED2_trypsin/TPP/MED4-Comet_ProtProp-overlap.png", dpi=300, transparent=True)
#plt.savefig("/home/millieginty/Documents/git-repos/denovo-etnp/MED4-Comet_ProtProp-overlap.png", dpi=300, transparent=True)
plt.show()

# %%
# Day 12 DB protein overlap

plt.figure(figsize=(5,5))
v = venn2(subsets=(115, 4, 13), \
          set_labels = ('Trypsin-digested T. weiss proteins', 'Non-digested T. weiss proteins'))
v.get_patch_by_id('100').set_alpha(1.0)

v.get_patch_by_id('100').set_color('#dd1c77')
v.get_patch_by_id('010').set_color('#fec44f')
#v.get_patch_by_id('001').set_color('#31a354')

v.get_patch_by_id('100').set_lw(1.5)
v.get_patch_by_id('010').set_lw(1.5)


plt.tight_layout()

# save figure in analysis and also in manuscript git repos
#plt.savefig("/home/millieginty/Documents/git-repos/2017-etnp/data/pro2020/RAL4_95_MED2_trypsin/TPP/MED4-Comet_ProtProp-overlap.png", dpi=300, transparent=True)
#plt.savefig("/home/millieginty/Documents/git-repos/denovo-etnp/MED4-Comet_ProtProp-overlap.png", dpi=300, transparent=True)
plt.show()

# %% [markdown]
# ## Protein overlap

# %%
import sys
import os

# %%
cd /home/millieginty/Documents/git-repos/rot-mayer/data/database-fastas/
# Out:
# /home/millieginty/Documents/git-repos/rot-mayer/data/database-fastas

# %%
ls
# Out:
# mmetsp_uniprot_tw_combo.fasta  T0-322_329_shared.txt

# %%
# use awk to make the fasta in single file format rather than interleaved (multiple lines/sequence)


# !awk '{if(NR==1) {print $0} else {if($0 ~ /^>/) {print "\n"$0} else {printf $0}}}' mmetsp_uniprot_tw_combo.fasta > mmetsp_uniprot_tw_combo_singleline.fasta

# %%
ls
# Out:
# mmetsp_uniprot_tw_combo.fasta             T0-322_329_shared.txt
# mmetsp_uniprot_tw_combo_singleline.fasta

# %%
# !grep -x -F -A 1 -f 'T0-322_329_shared.txt' 'mmetsp_uniprot_tw_combo_singleline.fasta' >> output.txt

# %% [markdown]
# ### Couldn't figure it out in python, but [Galaxy](usegalaxy.org/)'s `Filter FASTA sequences by ID` tool work's perfectly, so I output the results from that in the VennDrawer output analyses subdirectory.

# %%
# A script for extracting certain sequences from within a FASTA file.
 
# First, convert FASTA file into file with one line per sequence.
# Make sure the name of your FASTA file doesn't contain any dots
# besides the one before the extension!

linenum = 0
onelinefile = 'mmetsp_uniprot_tw_combo_singleline.fasta' + sys.argv[1].partition('.')[0] + '.tmp'
with open(onelinefile, 'w') as outfile:
    for line in open(sys.argv[1], 'r'):
        line = line.strip()
        if len(line) > 0:
            if line[0] == '>':
                if linenum == 0:
                    outfile.write(line + '\t')
                    linenum += 1
                else:
                    outfile.write('\n' + line + '\t')
            else:
                outfile.write(line)
 
# Populate a dictionary using the 'allononeline' file
all_seqs = {}
with open(onelinefile, 'r') as allseqsfile:
    for line in allseqsfile:
        line = line.strip().split('\t')
        all_seqs[line[0][1:]] = line[1]
 
# Generate a set of the sequences you wish to retrieve
desired_seqs = set()
with open(sys.argv[2], 'r') as listfile:
    for line in listfile:
        desired_seqs.add(line.strip())
 
# Find the overlap between the total sequences and the desired ones
all_seqs_names = set(all_seqs.keys())
toextract = all_seqs_names.intersection(desired_seqs)
 
# Use 'toextract' set to generate desired file
with open('T0-322_329_shared.txt' + sys.argv[1], 'w') as extractfile:
    for name in toextract:
        extractfile.write('>' + name + '\n' + all_seqs[name] + '\n')
 
os.remove(onelinefile)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-23-5d1a7e0c2bbf> in <module>
#       8 onelinefile = 'mmetsp_uniprot_tw_combo_singleline.fasta' + sys.argv[1].partition('.')[0] + '.tmp'
#       9 with open(onelinefile, 'w') as outfile:
# ---> 10     for line in open(sys.argv[1], 'r'):
#      11         line = line.strip()
#      12         if len(line) > 0:
#
# FileNotFoundError: [Errno 2] No such file or directory: '-f'

# %% [markdown]
# ### Sorting and visualizing UniPept lowest common ancestor analyses over diatom degradation experiment
#
# #### Beginning with: LCA peptides in csvs
#
# #### Goal: spectral abundance-corrected (NAAF) algal and bacterial peptide over the 4 timepoints

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# read the data into pandas dataframes
tryp_322_DB = pd.read_csv("/home/millieginty/Documents/git-repos/rot-mayer/analyses/unipept/lca/cleaned/T0-322-trypsin-lca-DB.csv", index_col=0)

tryp_322_DB.head(6)
# Out:
#                                  lca superkingdom kingdom subkingdom  \
# peptide
# LPQVEGTGGDVQPSQDLVR             root          NaN     NaN        NaN
# VLGQNEAVDAVSNALR                root          NaN     NaN        NaN
# ALDLLDEAASSLR                   root          NaN     NaN        NaN
# VTDAELAEVLAR                    root          NaN     NaN        NaN
# STEFDNLLLVGPLAGK                 NaN          NaN     NaN        NaN
# SKNVQVFVEK           Bacillariophyta    Eukaryota     NaN        NaN
#
#                     superphylum           phylum subphylum superclass class  \
# peptide
# LPQVEGTGGDVQPSQDLVR         NaN              NaN       NaN        NaN   NaN
# VLGQNEAVDAVSNALR            NaN              NaN       NaN        NaN   NaN
# ALDLLDEAASSLR               NaN              NaN       NaN        NaN   NaN
# VTDAELAEVLAR                NaN              NaN       NaN        NaN   NaN
# STEFDNLLLVGPLAGK            NaN              NaN       NaN        NaN   NaN
# SKNVQVFVEK                  NaN  Bacillariophyta       NaN        NaN   NaN
#
#                     subclass  ... tribe subtribe genus subgenus species group  \
# peptide                       ...
# LPQVEGTGGDVQPSQDLVR      NaN  ...   NaN      NaN   NaN      NaN     NaN   NaN
# VLGQNEAVDAVSNALR         NaN  ...   NaN      NaN   NaN      NaN     NaN   NaN
# ALDLLDEAASSLR            NaN  ...   NaN      NaN   NaN      NaN     NaN   NaN
# VTDAELAEVLAR             NaN  ...   NaN      NaN   NaN      NaN     NaN   NaN
# STEFDNLLLVGPLAGK         NaN  ...   NaN      NaN   NaN      NaN     NaN   NaN
# SKNVQVFVEK               NaN  ...   NaN      NaN   NaN      NaN     NaN   NaN
#
#                     species.1 subgroup species.2 subspecies
# peptide
# LPQVEGTGGDVQPSQDLVR       NaN      NaN       NaN        NaN
# VLGQNEAVDAVSNALR          NaN      NaN       NaN        NaN
# ALDLLDEAASSLR             NaN      NaN       NaN        NaN
# VTDAELAEVLAR              NaN      NaN       NaN        NaN
# STEFDNLLLVGPLAGK          NaN      NaN       NaN        NaN
# SKNVQVFVEK                NaN      NaN       NaN        NaN
#
# [6 rows x 29 columns]

# %%
# keep only the rows where kingdom = Bacteria

tryp_322_DB_Bac1 = tryp_322_DB.loc[(tryp_322_DB['kingdom'] == 'Bacteria')]

tryp_322_DB_Bac2 = tryp_322_DB.loc[(tryp_322_DB['subkingdom'] == 'Bacteria')]

print('# of kingdom = ', len(tryp_322_DB_Bac1))

print('# of subkingdom = ', len(tryp_322_DB_Bac2))

frames = [tryp_322_DB_Bac1, tryp_322_DB_Bac2]
  
tryp_322_DB_Bac = pd.concat(frames)

print('# of total Bacteria peptides = ', len(tryp_322_DB_Bac))

tryp_322_DB_Bac.head()
# Out:
# # of kingdom =  8
# # of subkingdom =  1
# # of total Bacteria peptides =  9
#                        lca   superkingdom   kingdom subkingdom superphylum  \
# peptide
# QGYSNPR        Barnesiella    viscericola  Bacteria        NaN         NaN
# DSPPALALK  Verrucomicrobia      bacterium  Bacteria        NaN         NaN
# SVDPYDR       Streptomyces  violaceoruber  Bacteria        NaN         NaN
# NDEALAFLR      Chloroflexi      bacterium  Bacteria        NaN         NaN
# SGDCTQER     Myxococcaceae      bacterium  Bacteria        NaN         NaN
#
#           phylum        subphylum     superclass         class  \
# peptide
# QGYSNPR      NaN    Bacteroidetes            NaN           NaN
# DSPPALALK    NaN  Verrucomicrobia            NaN           NaN
# SVDPYDR      NaN   Actinobacteria            NaN           NaN
# NDEALAFLR    NaN      Chloroflexi            NaN           NaN
# SGDCTQER     NaN   Proteobacteria  delta/epsilon  subdivisions
#
#                  subclass  ...          tribe subtribe genus      subgenus  \
# peptide                    ...
# QGYSNPR       Bacteroidia  ...            NaN      NaN   NaN   Barnesiella
# DSPPALALK             NaN  ...            NaN      NaN   NaN           NaN
# SVDPYDR    Actinobacteria  ...            NaN      NaN   NaN  Streptomyces
# NDEALAFLR             NaN  ...            NaN      NaN   NaN           NaN
# SGDCTQER              NaN  ...  Myxococcaceae      NaN   NaN           NaN
#
#           species group species.1         subgroup      species.2 subspecies
# peptide
# QGYSNPR       NaN   NaN       NaN      Barnesiella    viscericola        NaN
# DSPPALALK     NaN   NaN       NaN  Verrucomicrobia      bacterium        NaN
# SVDPYDR       NaN   NaN       NaN     Streptomyces  violaceoruber        NaN
# NDEALAFLR     NaN   NaN       NaN      Chloroflexi      bacterium        NaN
# SGDCTQER      NaN   NaN       NaN              NaN  Myxococcaceae  bacterium
#
# [5 rows x 29 columns]

# %%
# keep only the rows where phylum = Bacteria

tryp_322_DB_Dia1 = tryp_322_DB.loc[(tryp_322_DB['phylum'] == 'Bacillariophyta')]

tryp_322_DB_Dia2 = tryp_322_DB.loc[(tryp_322_DB['subphylum'] == 'Bacillariophyta')]

print('# of phylum = ', len(tryp_322_DB_Dia1))

print('# of subphylum = ', len(tryp_322_DB_Dia2))

frames = [tryp_322_DB_Dia1, tryp_322_DB_Dia2]
  
tryp_322_DB_Dia = pd.concat(frames)

print('# of total diatom peptides = ', len(tryp_322_DB_Dia))

tryp_322_DB_Dia.head()
# Out:
# # of phylum =  33
# # of subphylum =  28
# # of total diatom peptides =  61
#                                  lca superkingdom kingdom subkingdom  \
# peptide
# SKNVQVFVEK           Bacillariophyta    Eukaryota     NaN        NaN
# SELLCGTDGLPHLVADGR   Bacillariophyta    Eukaryota     NaN        NaN
# DVPGTGNEFVGDFR       Bacillariophyta    Eukaryota     NaN        NaN
# DVTGEGEFVGDFR       Thalassiosirales    Eukaryota     NaN        NaN
# NGALDFGWDK           Bacillariophyta    Eukaryota     NaN        NaN
#
#                    superphylum           phylum subphylum superclass  \
# peptide
# SKNVQVFVEK                 NaN  Bacillariophyta       NaN        NaN
# SELLCGTDGLPHLVADGR         NaN  Bacillariophyta       NaN        NaN
# DVPGTGNEFVGDFR             NaN  Bacillariophyta       NaN        NaN
# DVTGEGEFVGDFR              NaN  Bacillariophyta       NaN        NaN
# NGALDFGWDK                 NaN  Bacillariophyta       NaN        NaN
#
#                                   class               subclass  ... tribe  \
# peptide                                                         ...
# SKNVQVFVEK                          NaN                    NaN  ...   NaN
# SELLCGTDGLPHLVADGR                  NaN                    NaN  ...   NaN
# DVPGTGNEFVGDFR                      NaN                    NaN  ...   NaN
# DVTGEGEFVGDFR       Coscinodiscophyceae  Thalassiosirophycidae  ...   NaN
# NGALDFGWDK                          NaN                    NaN  ...   NaN
#
#                    subtribe genus subgenus species group species.1 subgroup  \
# peptide
# SKNVQVFVEK              NaN   NaN      NaN     NaN   NaN       NaN      NaN
# SELLCGTDGLPHLVADGR      NaN   NaN      NaN     NaN   NaN       NaN      NaN
# DVPGTGNEFVGDFR          NaN   NaN      NaN     NaN   NaN       NaN      NaN
# DVTGEGEFVGDFR           NaN   NaN      NaN     NaN   NaN       NaN      NaN
# NGALDFGWDK              NaN   NaN      NaN     NaN   NaN       NaN      NaN
#
#                    species.2 subspecies
# peptide
# SKNVQVFVEK               NaN        NaN
# SELLCGTDGLPHLVADGR       NaN        NaN
# DVPGTGNEFVGDFR           NaN        NaN
# DVTGEGEFVGDFR            NaN        NaN
# NGALDFGWDK               NaN        NaN
#
# [5 rows x 29 columns]

# %% [markdown]
# ### Now I want to read in the file containing the stripped peptides with NAAF values
# ####  - NAAF stands for 'noramlized area abunace factor'
#
# ### I want to join the dataframes if they share an index (stripped peptide with equated leucine and isoleucines)
# #### - That means I'll reindex the processed peptide file

# %%
tryp_322_DB_NAAF = pd.read_csv("/home/millieginty/Documents/git-repos/rot-mayer/data/processed/I-L_NAAFs/T0_322_trypsin_DB_peptides.csv")

tryp_322_DB_NAAF.set_index('stripped_IL')
tryp_322_DB_NAAF = tryp_322_DB_NAAF.loc[:, ~tryp_322_DB_NAAF.columns.str.contains('^Unnamed')]

tryp_322_DB_NAAF.head()
# Out:
#            stripped_IL         Area     NAAF_num.
# 0  LPQVEGTGGDVQPSQDLVR  134000000.0  7.052632e+06
# 1     VLGQNEAVDAVSNALR  142000000.0  8.875000e+06
# 2        ALDLLDEAASSLR  171000000.0  1.315385e+07
# 3         VTDAELAEVLAR  192000000.0  1.600000e+07
# 4     STEFDNLLLVGPLAGK      78300.0  4.893750e+03
